# %%
import mlflow
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier,
)
from sklearn.metrics import accuracy_score
from sklearn.dummy import DummyClassifier
from sklearn.preprocessing import StandardScaler
import pandas as pd
from mlflow.models import infer_signature
# import logging

# logging.getLogger("mlflow").setLevel(logging.DEBUG)

# %%
# Указываем доступ в БД
# with open("../database.env", "r") as file:
with open("database.env", "r") as file:    

    lines = file.readlines()
    user = lines[0].split("=")[-1][:-1]
    password = lines[1].split("=")[-1][:-1]
    db = lines[2].split("=")[-1]
print(user, password, db)
sql_string = f"postgresql://{user}:{password}@postgres:5432/{db}"
mlflow.set_tracking_uri(sql_string)
# mlflow.set_tracking_uri("../data/mlruns")
# ARTIFACT_LOCATION = "../data/mlruns"
ARTIFACT_LOCATION = "/app/data/mlflow_artifacts"
# Out:
# mlflow_user magical_password mlflow_db

# %% [markdown]
# # Without scaling

# %%
random_state = 42

models = [
    LogisticRegression(solver="saga", random_state=random_state, n_jobs=-1),
    GaussianNB(),
    KNeighborsClassifier(n_neighbors=3, n_jobs=-1),
    DecisionTreeClassifier(random_state=random_state),
    RandomForestClassifier(n_estimators=7, random_state=random_state, n_jobs=-1),
    MLPClassifier(
        hidden_layer_sizes=(45, 30, 15),
        solver="sgd",
        learning_rate_init=0.01,
        max_iter=500,
        random_state=random_state,
    ),
    AdaBoostClassifier(random_state=random_state),
    GradientBoostingClassifier(random_state=random_state),
    DummyClassifier(strategy="most_frequent", random_state=random_state)
]

print("Models appended...")
# Out:
# Models appended...

# %% [markdown]
# Loading the data:

# %%
processed = pd.read_pickle("data/processed_df.pkl")
X = processed.drop(columns=["Credit_Score"])
y = processed["Credit_Score"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42, stratify=y
)

# %%
X
# Out:
#        Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0       23       19114.12            1824.843333                  3
# 3       23       19114.12            1824.843333                  3
# 4       23       19114.12            1824.843333                  3
# 5       23       19114.12            1824.843333                  3
# 6       23       19114.12            1824.843333                  3
# ...    ...            ...                    ...                ...
# 99994   25       39628.99            3359.415833                  4
# 99995   25       39628.99            3359.415833                  4
# 99996   25       39628.99            3359.415833                  4
# 99998   25       39628.99            3359.415833                  4
# 99999   25       39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                    4              3            4                    3
# 3                    4              3            4                    5
# 4                    4              3            4                    6
# 5                    4              3            4                    8
# 6                    4              3            4                    3
# ...                ...            ...          ...                  ...
# 99994                6              7            2                   20
# 99995                6              7            2                   23
# 99996                6              7            2                   18
# 99998                6              7            2                   20
# 99999                6              7            2                   18
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  ...  Credit_Mix_Standard  \
# 0                           7                 11.27  ...                False
# 3                           4                  6.27  ...                False
# 4                           4                 11.27  ...                False
# 5                           4                  9.27  ...                False
# 6                           4                 11.27  ...                False
# ...                       ...                   ...  ...                  ...
# 99994                       6                  9.50  ...                False
# 99995                       7                 11.50  ...                False
# 99996                       7                 11.50  ...                False
# 99998                       1                 11.50  ...                False
# 99999                       6                 11.50  ...                False
#
#        Credit_Mix__  Payment_of_Min_Amount_No  Payment_of_Min_Amount_Yes  \
# 0              True                      True                      False
# 3             False                      True                      False
# 4             False                      True                      False
# 5             False                      True                      False
# 6             False                      True                      False
# ...             ...                       ...                        ...
# 99994          True                      True                      False
# 99995          True                      True                      False
# 99996          True                      True                      False
# 99998         False                      True                      False
# 99999         False                      True                      False
#
#        Payment_Behaviour_High_spent_Large_value_payments  \
# 0                                                  False
# 3                                                  False
# 4                                                  False
# 5                                                  False
# 6                                                  False
# ...                                                  ...
# 99994                                              False
# 99995                                               True
# 99996                                              False
# 99998                                              False
# 99999                                              False
#
#        Payment_Behaviour_High_spent_Medium_value_payments  \
# 0                                                  False
# 3                                                  False
# 4                                                   True
# 5                                                  False
# 6                                                  False
# ...                                                  ...
# 99994                                               True
# 99995                                              False
# 99996                                               True
# 99998                                              False
# 99999                                              False
#
#        Payment_Behaviour_High_spent_Small_value_payments  \
# 0                                                   True
# 3                                                  False
# 4                                                  False
# 5                                                  False
# 6                                                  False
# ...                                                  ...
# 99994                                              False
# 99995                                              False
# 99996                                              False
# 99998                                              False
# 99999                                              False
#
#        Payment_Behaviour_Low_spent_Large_value_payments  \
# 0                                                 False
# 3                                                 False
# 4                                                 False
# 5                                                 False
# 6                                                 False
# ...                                                 ...
# 99994                                             False
# 99995                                             False
# 99996                                             False
# 99998                                              True
# 99999                                             False
#
#        Payment_Behaviour_Low_spent_Medium_value_payments  \
# 0                                                  False
# 3                                                  False
# 4                                                  False
# 5                                                  False
# 6                                                  False
# ...                                                  ...
# 99994                                              False
# 99995                                              False
# 99996                                              False
# 99998                                              False
# 99999                                              False
#
#        Payment_Behaviour_Low_spent_Small_value_payments
# 0                                                 False
# 3                                                  True
# 4                                                 False
# 5                                                 False
# 6                                                  True
# ...                                                 ...
# 99994                                             False
# 99995                                             False
# 99996                                             False
# 99998                                             False
# 99999                                             False
#
# [60557 rows x 59 columns]

# %%
# %store -r X y
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.33, random_state=42, stratify=y
# )

# %%
def run_experiments(experiment_name, suffix=None):
    try:
        experiment_id = mlflow.create_experiment(experiment_name,   artifact_location=ARTIFACT_LOCATION)
    except mlflow.exceptions.MlflowException:
        experiment_id = mlflow.get_experiment_by_name(experiment_name).experiment_id
    for model in models:
        if suffix == None:
            run_n = model.__class__.__name__
        else:
            run_n = model.__class__.__name__+suffix
        with mlflow.start_run(run_name=run_n, experiment_id=experiment_id) as parent_run:
            kfold = KFold(n_splits=5, random_state=42, shuffle=True)
            mlflow.log_param("Model", model.__class__.__name__)
            mlflow.log_params(model.model.get_params())
            for fold, (train_index, test_index) in enumerate(kfold.split(X_train)):
                X_train_fold = X_train.iloc[train_index]
                X_test_fold = X_train.iloc[test_index]
                y_train_fold = y_train.iloc[train_index]
                y_test_fold = y_train.iloc[test_index]
                
                signature = infer_signature(X_test_fold, y_test_fold)
                model.fit(X_train_fold, y_train_fold)

                # Start nested MLflow run
                with mlflow.start_run(run_name=f"Fold {fold}", nested=True, experiment_id=experiment_id):
                    mlflow.log_param("Model", model.__class__.__name__)
                    # Log metrics
                    model_uri = mlflow.sklearn.log_model(
                        model, "model", signature=signature
                    ).model_uri 
                    mlflow.evaluate(
                        model_uri,
                        pd.concat([X_test_fold, y_test_fold], axis=1),
                        targets="Credit_Score",
                        model_type="classifier",
                    )
                    mlflow.log_params(model.model.get_params())
            signature = infer_signature(X_test, y_test)
            model.fit(X_train, y_train)
            model_uri = mlflow.sklearn.log_model(
                    model, "model", signature=signature
                ).model_uri 
            mlflow.evaluate(
                model_uri,
                pd.concat([X_test, y_test], axis=1),
                targets="Credit_Score",
                model_type="classifier",
            )

# %%
run_experiments("Default Models Comparison (without scaling)")
# Out:
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/29 13:18:16 WARNING mlflow.utils.validation: Tag value '[{"run_id": "f403be99bc9946d68fe81d1e6e862ae4", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:18:16 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/f403be99bc9946d68fe81d1e6e862ae4/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:18:19 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:18:19 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:18:19 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:18:20 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/29 13:18:28 WARNING mlflow.utils.validation: Tag value '[{"run_id": "57c1bd0b09734157a5327f4979bb1a7b", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:18:28 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/57c1bd0b09734157a5327f4979bb1a7b/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:18:30 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:18:30 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:18:31 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:18:31 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/29 13:18:40 WARNING mlflow.utils.validation: Tag value '[{"run_id": "7c297b3ef82547408617088148492f55", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:18:40 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/7c297b3ef82547408617088148492f55/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:18:42 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:18:42 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:18:42 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:18:43 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/29 13:18:51 WARNING mlflow.utils.validation: Tag value '[{"run_id": "0cadb2c97d4b4456a8ed7da5c7d37210", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:18:51 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/0cadb2c97d4b4456a8ed7da5c7d37210/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:18:53 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:18:53 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:18:54 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:18:54 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/29 13:19:02 WARNING mlflow.utils.validation: Tag value '[{"run_id": "23304a816e904728ad21702caf9cb67b", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:19:02 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/23304a816e904728ad21702caf9cb67b/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:05 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:19:05 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:19:05 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:19:06 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/29 13:19:18 WARNING mlflow.utils.validation: Tag value '[{"run_id": "c9adcee93402497bb6ec8f5a75a4094a", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:19:18 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/c9adcee93402497bb6ec8f5a75a4094a/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:23 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:19:23 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:19:24 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:19:25 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:28 WARNING mlflow.utils.validation: Tag value '[{"run_id": "b1a929c46a9f45fca9ecabe01dc6bc8a", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:19:28 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/b1a929c46a9f45fca9ecabe01dc6bc8a/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:31 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:19:31 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:19:31 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:19:32 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:35 WARNING mlflow.utils.validation: Tag value '[{"run_id": "e8dc68c4cb94416fa8de8a167d7ba647", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:19:35 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/e8dc68c4cb94416fa8de8a167d7ba647/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:38 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:19:38 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:19:38 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:19:39 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:42 WARNING mlflow.utils.validation: Tag value '[{"run_id": "8e8d55c75d244dc6931886baa5ad6832", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:19:42 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/8e8d55c75d244dc6931886baa5ad6832/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:45 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:19:45 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:19:45 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:19:46 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:49 WARNING mlflow.utils.validation: Tag value '[{"run_id": "3c4aa0752e664922a075c3c07843073d", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:19:49 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/3c4aa0752e664922a075c3c07843073d/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:51 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:19:52 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:19:52 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:19:52 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:56 WARNING mlflow.utils.validation: Tag value '[{"run_id": "0c0418973c1945b09142067e47619824", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:19:56 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/0c0418973c1945b09142067e47619824/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:19:58 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:19:58 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:19:58 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:19:59 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:06 WARNING mlflow.utils.validation: Tag value '[{"run_id": "99e9ce265ee04e57a1f1465d3077afa5", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:20:06 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/99e9ce265ee04e57a1f1465d3077afa5/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:12 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:20:12 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:20:12 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:20:13 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:17 WARNING mlflow.utils.validation: Tag value '[{"run_id": "d6d6489456644ced859f22204d01cec9", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:20:17 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/d6d6489456644ced859f22204d01cec9/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:19 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:20:20 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:20:21 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:20:22 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:26 WARNING mlflow.utils.validation: Tag value '[{"run_id": "d9f159df33a24e81bf21f4a4c174ff49", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:20:26 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/d9f159df33a24e81bf21f4a4c174ff49/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:28 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:20:29 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:20:31 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:20:32 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:35 WARNING mlflow.utils.validation: Tag value '[{"run_id": "ca0531d1e78a4ca7bddfae70123f0ff2", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:20:35 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/ca0531d1e78a4ca7bddfae70123f0ff2/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:38 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:20:39 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:20:40 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:20:41 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:45 WARNING mlflow.utils.validation: Tag value '[{"run_id": "2cc379d8920946159bc226138cf09a0e", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:20:45 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/2cc379d8920946159bc226138cf09a0e/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:20:47 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:20:48 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:20:49 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:20:50 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# ...
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:17 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:18 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:30:21 WARNING mlflow.utils.validation: Tag value '[{"run_id": "f7ae57b718b84045801c83bd7461fcf7", "artifact_path": "model", "utc_time_created": "2024-...' (5567 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:30:21 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/f7ae57b718b84045801c83bd7461fcf7/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:30:24 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:30:24 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:24 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:25 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:30:28 WARNING mlflow.utils.validation: Tag value '[{"run_id": "2c421e0f29224ecdbfb12c7aa3ce85fa", "artifact_path": "model", "utc_time_created": "2024-...' (5567 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:30:28 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/2c421e0f29224ecdbfb12c7aa3ce85fa/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:30:31 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:30:31 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:31 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:32 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:30:35 WARNING mlflow.utils.validation: Tag value '[{"run_id": "73622633f72c4ba49ea3531ede78e15a", "artifact_path": "model", "utc_time_created": "2024-...' (5567 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:30:35 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/73622633f72c4ba49ea3531ede78e15a/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:30:38 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:30:38 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:38 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:39 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:30:46 WARNING mlflow.utils.validation: Tag value '[{"run_id": "44505abc5d81455b908bc2d33f7082fa", "artifact_path": "model", "utc_time_created": "2024-...' (5567 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:30:46 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/44505abc5d81455b908bc2d33f7082fa/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/29 13:30:51 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:30:51 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:52 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 13:30:53 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.

# %% [markdown]
# # With scaling

# %%
std_scaler = StandardScaler().set_output(transform="pandas")
X_train = std_scaler.fit_transform(X_train)
X_test = std_scaler.transform(X_test)
X_train
# Out:
#             Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 21218  0.061845       0.683500               0.573484          -0.953959
# 55646  1.359144       0.961410               1.041592          -2.154176
# 53697  0.061845       1.639857               1.566141          -0.153815
# 3401  -0.586804       0.410584               0.451641          -0.153815
# 7661  -0.772133      -0.576694              -0.461440           0.246257
# ...         ...            ...                    ...                ...
# 4050  -0.494140      -0.401277              -0.398861           0.646330
# 74581  0.617831      -0.818893              -0.715745           0.646330
# 60633 -1.235454      -0.941403              -0.910977           1.846546
# 37654  1.266480      -0.211094              -0.100994          -0.953959
# 13701  0.432502       1.367700               1.387247          -0.153815
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 21218         0.252577      -1.579269     0.231387             0.410329
# 55646        -0.245518      -1.579269    -1.513686            -1.566132
# 53697        -0.743614       1.831133     0.231387            -0.933665
# 3401         -0.245518      -0.168068    -0.641150            -1.091781
# 7661          0.750673      -0.991269    -0.204881            -0.617431
# ...                ...            ...          ...                  ...
# 4050          0.750673       1.125532    -0.641150             0.726563
# 74581         0.750673       0.890332     2.412728             0.568446
# 60633         2.244961       1.125532     1.540192             2.465849
# 37654        -0.245518      -1.344069    -1.513686            -0.538372
# 13701         0.750673      -0.756069    -0.641150            -0.854606
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  ...  Credit_Mix_Standard  \
# 21218               -0.905534             -0.613394  ...            -0.847324
# 55646               -0.738044              0.141082  ...            -0.847324
# 53697                0.434385             -0.086534  ...             1.180187
# 3401                -0.403065              0.375064  ...             1.180187
# 7661                -0.570554              0.991060  ...             1.180187
# ...                       ...                   ...  ...                  ...
# 4050                 1.606813             -1.380603  ...            -0.847324
# 74581                1.104344             -0.521074  ...            -0.847324
# 60633                1.104344              2.643266  ...            -0.847324
# 37654               -1.575493              0.023294  ...            -0.847324
# 13701               -1.073024             -0.694572  ...            -0.847324
#
#        Credit_Mix__  Payment_of_Min_Amount_No  Payment_of_Min_Amount_Yes  \
# 21218     -0.502556                  1.387300                  -1.081249
# 55646     -0.502556                  1.387300                  -1.081249
# 53697     -0.502556                 -0.720825                  -1.081249
# 3401      -0.502556                  1.387300                  -1.081249
# 7661      -0.502556                 -0.720825                  -1.081249
# ...             ...                       ...                        ...
# 4050      -0.502556                 -0.720825                   0.924856
# 74581     -0.502556                 -0.720825                   0.924856
# 60633     -0.502556                 -0.720825                   0.924856
# 37654     -0.502556                  1.387300                  -1.081249
# 13701      1.989829                  1.387300                  -1.081249
#
#        Payment_Behaviour_High_spent_Large_value_payments  \
# 21218                                          -0.354210
# 55646                                          -0.354210
# 53697                                           2.823185
# 3401                                            2.823185
# 7661                                           -0.354210
# ...                                                  ...
# 4050                                           -0.354210
# 74581                                           2.823185
# 60633                                          -0.354210
# 37654                                           2.823185
# 13701                                          -0.354210
#
#        Payment_Behaviour_High_spent_Medium_value_payments  \
# 21218                                          -0.476633
# 55646                                          -0.476633
# 53697                                          -0.476633
# 3401                                           -0.476633
# 7661                                           -0.476633
# ...                                                  ...
# 4050                                           -0.476633
# 74581                                          -0.476633
# 60633                                          -0.476633
# 37654                                          -0.476633
# 13701                                          -0.476633
#
#        Payment_Behaviour_High_spent_Small_value_payments  \
# 21218                                          -0.372896
# 55646                                           2.681716
# 53697                                          -0.372896
# 3401                                           -0.372896
# 7661                                           -0.372896
# ...                                                  ...
# 4050                                           -0.372896
# 74581                                          -0.372896
# 60633                                          -0.372896
# 37654                                          -0.372896
# 13701                                          -0.372896
#
#        Payment_Behaviour_Low_spent_Large_value_payments  \
# 21218                                         -0.349210
# 55646                                         -0.349210
# 53697                                         -0.349210
# 3401                                          -0.349210
# 7661                                          -0.349210
# ...                                                 ...
# 4050                                           2.863604
# 74581                                         -0.349210
# 60633                                         -0.349210
# 37654                                         -0.349210
# 13701                                          2.863604
#
#        Payment_Behaviour_Low_spent_Medium_value_payments  \
# 21218                                           2.627905
# 55646                                          -0.380531
# 53697                                          -0.380531
# 3401                                           -0.380531
# 7661                                           -0.380531
# ...                                                  ...
# 4050                                           -0.380531
# 74581                                          -0.380531
# 60633                                          -0.380531
# 37654                                          -0.380531
# 13701                                          -0.380531
#
#        Payment_Behaviour_Low_spent_Small_value_payments
# 21218                                         -0.608213
# 55646                                         -0.608213
# 53697                                         -0.608213
# 3401                                          -0.608213
# 7661                                          -0.608213
# ...                                                 ...
# 4050                                          -0.608213
# 74581                                         -0.608213
# 60633                                          1.644162
# 37654                                         -0.608213
# 13701                                         -0.608213
#
# [40573 rows x 59 columns]

# %%
run_experiments("Model Comparison Experiment (with default params and scaling)", "_with scaling")
# Out:
# 2024/08/29 13:43:06 WARNING mlflow.utils.validation: Tag value '[{"run_id": "5b54aef386294d16bd40710fcfcbfeb6", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:43:06 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/5b54aef386294d16bd40710fcfcbfeb6/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:43:16 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:43:16 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:43:17 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:43:18 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:43:34 WARNING mlflow.utils.validation: Tag value '[{"run_id": "601f7f488eb34724a83d485189f830f7", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:43:34 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/601f7f488eb34724a83d485189f830f7/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:43:44 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:43:44 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:43:44 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:43:46 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:44:01 WARNING mlflow.utils.validation: Tag value '[{"run_id": "4392c77e9d5d4693b915d2f8d2b033ed", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:44:01 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/4392c77e9d5d4693b915d2f8d2b033ed/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:44:11 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:44:11 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:44:11 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:44:13 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:44:28 WARNING mlflow.utils.validation: Tag value '[{"run_id": "23daee9484ea45888fb1bfdeda1ee031", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:44:28 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/23daee9484ea45888fb1bfdeda1ee031/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:44:38 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:44:38 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:44:38 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:44:40 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:44:55 WARNING mlflow.utils.validation: Tag value '[{"run_id": "4c28f384fb3848b0a9122054047c467a", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:44:55 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/4c28f384fb3848b0a9122054047c467a/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:45:05 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:45:05 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:45:06 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:45:07 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:45:36 WARNING mlflow.utils.validation: Tag value '[{"run_id": "431697421e98405da9c4dcb55fc5ed33", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:45:37 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/431697421e98405da9c4dcb55fc5ed33/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:46:01 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:46:01 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:46:01 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:46:03 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:46:17 WARNING mlflow.utils.validation: Tag value '[{"run_id": "4250518dd5ab475c9508bcf599e47118", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:46:17 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/4250518dd5ab475c9508bcf599e47118/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:46:27 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:46:27 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:46:27 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:46:29 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:46:43 WARNING mlflow.utils.validation: Tag value '[{"run_id": "abf478f96e2d47b7bda28a2f82c6f2b3", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:46:43 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/abf478f96e2d47b7bda28a2f82c6f2b3/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:46:53 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:46:53 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:46:53 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:46:55 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:47:09 WARNING mlflow.utils.validation: Tag value '[{"run_id": "855eb010a21642a5bca0a61620add01e", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:47:09 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/855eb010a21642a5bca0a61620add01e/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:47:20 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:47:20 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:47:20 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:47:22 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:47:37 WARNING mlflow.utils.validation: Tag value '[{"run_id": "aba85da470b04e59ad10fe423ffa646c", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:47:37 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/aba85da470b04e59ad10fe423ffa646c/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:47:47 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:47:47 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:47:48 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:47:50 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:48:05 WARNING mlflow.utils.validation: Tag value '[{"run_id": "0a9172ca622e4924a28edd0b69b92ca8", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:48:05 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/0a9172ca622e4924a28edd0b69b92ca8/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:48:15 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:48:15 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:48:15 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:48:17 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:48:48 WARNING mlflow.utils.validation: Tag value '[{"run_id": "bf9781dbf4fb4076a998d612ffa181be", "artifact_path": "model", "utc_time_created": "2024-...' (5530 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:48:48 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/bf9781dbf4fb4076a998d612ffa181be/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:49:13 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:49:13 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/29 13:49:13 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:49:15 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:49:30 WARNING mlflow.utils.validation: Tag value '[{"run_id": "bdec8ecbf1564651820c2cb81f905459", "artifact_path": "model", "utc_time_created": "2024-...' (5534 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:49:30 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/bdec8ecbf1564651820c2cb81f905459/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:49:40 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:49:42 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:49:44 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:49:45 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:50:00 WARNING mlflow.utils.validation: Tag value '[{"run_id": "2c8538a2cd4943b8817250d517b84c2d", "artifact_path": "model", "utc_time_created": "2024-...' (5534 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:50:00 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/2c8538a2cd4943b8817250d517b84c2d/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:50:10 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:50:12 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:50:14 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:50:15 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:50:30 WARNING mlflow.utils.validation: Tag value '[{"run_id": "1790ed245fc7470f96631cd822373aed", "artifact_path": "model", "utc_time_created": "2024-...' (5534 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:50:30 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/1790ed245fc7470f96631cd822373aed/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:50:40 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:50:42 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:50:44 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:50:46 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:51:00 WARNING mlflow.utils.validation: Tag value '[{"run_id": "d3113a9437f54710b208250d2829e94d", "artifact_path": "model", "utc_time_created": "2024-...' (5534 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:51:00 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/d3113a9437f54710b208250d2829e94d/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:51:11 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:51:12 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:51:14 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:51:16 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:51:30 WARNING mlflow.utils.validation: Tag value '[{"run_id": "dd8e50de59f840c8ba504ed7335f6fbf", "artifact_path": "model", "utc_time_created": "2024-...' (5534 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:51:30 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/dd8e50de59f840c8ba504ed7335f6fbf/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:51:41 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:51:42 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:51:44 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:51:46 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:52:16 WARNING mlflow.utils.validation: Tag value '[{"run_id": "6ef15f0b745c4becbd38878faaa09695", "artifact_path": "model", "utc_time_created": "2024-...' (5534 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:52:16 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/6ef15f0b745c4becbd38878faaa09695/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:52:41 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:52:46 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:52:49 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:52:52 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:53:07 WARNING mlflow.utils.validation: Tag value '[{"run_id": "e707a5f04035459aa610171b03d7e586", "artifact_path": "model", "utc_time_created": "2024-...' (5532 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:53:07 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/e707a5f04035459aa610171b03d7e586/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:53:18 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:53:18 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:53:18 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:53:20 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:53:35 WARNING mlflow.utils.validation: Tag value '[{"run_id": "ced9c7591a6540868471259676dc47d9", "artifact_path": "model", "utc_time_created": "2024-...' (5532 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:53:35 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/ced9c7591a6540868471259676dc47d9/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:53:45 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:53:45 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:53:45 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:53:47 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:54:03 WARNING mlflow.utils.validation: Tag value '[{"run_id": "dbd933e207c843838bcbc7aafd1a96d7", "artifact_path": "model", "utc_time_created": "2024-...' (5532 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:54:03 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/dbd933e207c843838bcbc7aafd1a96d7/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:54:13 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:54:13 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:54:13 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:54:15 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:54:31 WARNING mlflow.utils.validation: Tag value '[{"run_id": "eaf31cb9bca9467c86cfa609ae0bc142", "artifact_path": "model", "utc_time_created": "2024-...' (5532 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:54:31 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/eaf31cb9bca9467c86cfa609ae0bc142/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:54:41 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:54:41 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:54:41 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:54:43 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:54:58 WARNING mlflow.utils.validation: Tag value '[{"run_id": "91d5afcb260c41c3a546f77e3643f2b5", "artifact_path": "model", "utc_time_created": "2024-...' (5532 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:54:58 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/91d5afcb260c41c3a546f77e3643f2b5/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:55:09 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:55:09 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:55:09 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:55:11 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:55:40 WARNING mlflow.utils.validation: Tag value '[{"run_id": "68a10e094c484fffab8d2619293b5298", "artifact_path": "model", "utc_time_created": "2024-...' (5533 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:55:40 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/68a10e094c484fffab8d2619293b5298/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:56:06 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:56:06 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:56:06 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:56:08 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:56:23 WARNING mlflow.utils.validation: Tag value '[{"run_id": "83ce65929cc64ae5a404d635ca292d6e", "artifact_path": "model", "utc_time_created": "2024-...' (5533 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:56:23 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/83ce65929cc64ae5a404d635ca292d6e/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:56:33 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:56:33 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:56:33 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:56:35 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:56:50 WARNING mlflow.utils.validation: Tag value '[{"run_id": "9554b5b7e2e94aae9ecf5666af582563", "artifact_path": "model", "utc_time_created": "2024-...' (5533 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:56:50 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/9554b5b7e2e94aae9ecf5666af582563/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:57:00 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:57:01 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:57:01 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:57:03 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:57:17 WARNING mlflow.utils.validation: Tag value '[{"run_id": "8a18a4adf67b42f0ac8780cbd56d104d", "artifact_path": "model", "utc_time_created": "2024-...' (5533 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:57:17 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/8a18a4adf67b42f0ac8780cbd56d104d/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:57:28 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:57:28 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:57:28 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:57:30 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:57:45 WARNING mlflow.utils.validation: Tag value '[{"run_id": "25681a7f159741f6bba5a5e99c500378", "artifact_path": "model", "utc_time_created": "2024-...' (5533 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:57:45 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/25681a7f159741f6bba5a5e99c500378/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:57:55 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:57:55 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:57:56 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:57:58 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:58:13 WARNING mlflow.utils.validation: Tag value '[{"run_id": "adefc3da2bbf491c9faaf015cb888863", "artifact_path": "model", "utc_time_created": "2024-...' (5533 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:58:13 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/adefc3da2bbf491c9faaf015cb888863/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:58:23 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:58:23 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:58:24 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:58:26 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 13:58:56 WARNING mlflow.utils.validation: Tag value '[{"run_id": "30bac3aa36754f63a84a6e26b2555eff", "artifact_path": "model", "utc_time_created": "2024-...' (5533 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 13:58:56 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/30bac3aa36754f63a84a6e26b2555eff/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 13:59:20 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 13:59:20 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 13:59:21 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 13:59:23 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:00:52 WARNING mlflow.utils.validation: Tag value '[{"run_id": "89551fc19df84fb99ec6d91a65fc5b4e", "artifact_path": "model", "utc_time_created": "2024-...' (5531 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:00:52 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/89551fc19df84fb99ec6d91a65fc5b4e/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:01:03 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:01:03 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:01:03 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:01:05 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:02:04 WARNING mlflow.utils.validation: Tag value '[{"run_id": "5fbf6db85c24411ca354ba475c8e7951", "artifact_path": "model", "utc_time_created": "2024-...' (5531 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:02:04 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/5fbf6db85c24411ca354ba475c8e7951/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:02:14 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:02:14 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:02:14 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:02:16 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:03:20 WARNING mlflow.utils.validation: Tag value '[{"run_id": "ed4dd23b12d64202b2f53c645301a6ec", "artifact_path": "model", "utc_time_created": "2024-...' (5531 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:03:20 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/ed4dd23b12d64202b2f53c645301a6ec/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:03:30 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:03:30 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:03:30 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:03:32 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:04:39 WARNING mlflow.utils.validation: Tag value '[{"run_id": "af631b75302142f29da76287f4e38977", "artifact_path": "model", "utc_time_created": "2024-...' (5531 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:04:39 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/af631b75302142f29da76287f4e38977/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:04:49 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:04:49 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:04:50 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:04:52 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:06:18 WARNING mlflow.utils.validation: Tag value '[{"run_id": "0fd67e3e03ba4647b0f49d75e2eb7ef2", "artifact_path": "model", "utc_time_created": "2024-...' (5531 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:06:18 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/0fd67e3e03ba4647b0f49d75e2eb7ef2/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:06:28 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:06:28 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:06:28 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:06:30 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:08:27 WARNING mlflow.utils.validation: Tag value '[{"run_id": "ae327d05dc7b48a89f76441e642e521d", "artifact_path": "model", "utc_time_created": "2024-...' (5531 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:08:27 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/ae327d05dc7b48a89f76441e642e521d/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:08:52 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:08:52 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:08:52 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:08:55 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 2024/08/29 14:09:14 WARNING mlflow.utils.validation: Tag value '[{"run_id": "368ede5151c648dbbfc04abc1707396f", "artifact_path": "model", "utc_time_created": "2024-...' (5531 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:09:14 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/368ede5151c648dbbfc04abc1707396f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:09:24 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:09:24 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:09:25 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:09:27 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 2024/08/29 14:09:45 WARNING mlflow.utils.validation: Tag value '[{"run_id": "d8e3e96d27a94e4ab576d32bf338afde", "artifact_path": "model", "utc_time_created": "2024-...' (5531 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:09:45 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/d8e3e96d27a94e4ab576d32bf338afde/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:09:56 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:09:56 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:09:56 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# ...
# 2024/08/29 14:17:11 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:17:12 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:18:07 WARNING mlflow.utils.validation: Tag value '[{"run_id": "f44b2052db7e4c9ebe978cac479c1c65", "artifact_path": "model", "utc_time_created": "2024-...' (5532 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:18:07 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/f44b2052db7e4c9ebe978cac479c1c65/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:18:18 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:18:18 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:18:18 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:18:20 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:19:41 WARNING mlflow.utils.validation: Tag value '[{"run_id": "7db161907bbb473fb21c00acf825d898", "artifact_path": "model", "utc_time_created": "2024-...' (5532 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:19:41 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/7db161907bbb473fb21c00acf825d898/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:20:06 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:20:06 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/29 14:20:07 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/29 14:20:09 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:20:23 WARNING mlflow.utils.validation: Tag value '[{"run_id": "e0ccf5381f9043b0a714e5b1a9cca668", "artifact_path": "model", "utc_time_created": "2024-...' (5529 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:20:23 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/e0ccf5381f9043b0a714e5b1a9cca668/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:20:33 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:20:33 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:20:33 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:20:35 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:20:49 WARNING mlflow.utils.validation: Tag value '[{"run_id": "117b6482da044704baa5848a208820ff", "artifact_path": "model", "utc_time_created": "2024-...' (5529 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:20:49 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/117b6482da044704baa5848a208820ff/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:21:00 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:21:00 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:21:00 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:21:02 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:21:16 WARNING mlflow.utils.validation: Tag value '[{"run_id": "6ea4a5f3fd31485aae2d08db9af41641", "artifact_path": "model", "utc_time_created": "2024-...' (5529 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:21:16 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/6ea4a5f3fd31485aae2d08db9af41641/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:21:27 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:21:27 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:21:27 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:21:29 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:21:43 WARNING mlflow.utils.validation: Tag value '[{"run_id": "9867435d54104c548d46746ad8384dd2", "artifact_path": "model", "utc_time_created": "2024-...' (5529 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:21:43 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/9867435d54104c548d46746ad8384dd2/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:21:53 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:21:53 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:21:53 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:21:55 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:22:09 WARNING mlflow.utils.validation: Tag value '[{"run_id": "82c4f5eb6ab44d3992ff653421620813", "artifact_path": "model", "utc_time_created": "2024-...' (5529 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:22:09 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/82c4f5eb6ab44d3992ff653421620813/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:22:19 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:22:19 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:22:19 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:22:21 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# 2024/08/29 14:22:51 WARNING mlflow.utils.validation: Tag value '[{"run_id": "4236e74c2f0b4369b3a874db78749da1", "artifact_path": "model", "utc_time_created": "2024-...' (5529 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/29 14:22:51 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/data/mlflow_artifacts/4236e74c2f0b4369b3a874db78749da1/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/08/29 14:23:15 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/29 14:23:15 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:23:15 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/29 14:23:17 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
