# %%
import mlflow
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier,
)
from sklearn.metrics import accuracy_score
from sklearn.dummy import DummyClassifier
from sklearn.preprocessing import StandardScaler
import pandas as pd
import logging
logging.getLogger("mlflow").setLevel(logging.DEBUG)

# %%
# Указываем доступ в БД
# with open("../database.env", "r") as file:
with open("database.env", "r") as file:    

    lines = file.readlines()
    user = lines[0].split("=")[-1][:-1]
    password = lines[1].split("=")[-1][:-1]
    db = lines[2].split("=")[-1]
print(user, password, db)
sql_string = f"postgresql://{user}:{password}@postgres:5432/{db}"
mlflow.set_tracking_uri(sql_string)
# mlflow.set_tracking_uri("../data/mlruns")
# ARTIFACT_LOCATION = "../data/mlruns"
ARTIFACT_LOCATION = "/app/mlflow_artifacts"
# Out:
# mlflow_user magical_password mlflow_db

# %% [markdown]
# # Without scaling

# %%
random_state = 42

models = [
    LogisticRegression(solver="saga", random_state=random_state, n_jobs=-1),
    GaussianNB(),
    KNeighborsClassifier(n_neighbors=3, n_jobs=-1),
     DecisionTreeClassifier(random_state=random_state),
     RandomForestClassifier(n_estimators=7, random_state=random_state, n_jobs=-1),
     MLPClassifier(
            hidden_layer_sizes=(45, 30, 15),
            solver="sgd",
            learning_rate_init=0.01,
            max_iter=500,
            random_state=random_state,
        ),
     AdaBoostClassifier(random_state=random_state),
     GradientBoostingClassifier(random_state=random_state),
     DummyClassifier(strategy="most_frequent", random_state=random_state),
]

print("Models appended...")
# Out:
# Models appended...

# %% [markdown]
# Loading the data:

# %%
# %store -r X y

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42, stratify=y
)

# %%
from mlflow.models import infer_signature
def run_experiments(experiment_name):
    try:
        experiment_id = mlflow.create_experiment(experiment_name,   artifact_location=ARTIFACT_LOCATION)
    except mlflow.exceptions.MlflowException:
        experiment_id = mlflow.get_experiment_by_name(experiment_name).experiment_id
    for model in models:
        with mlflow.start_run(run_name=model.__class__.__name__, experiment_id=experiment_id) as parent_run:
            kfold = KFold(n_splits=5, random_state=42, shuffle=True)
            mlflow.log_param("Model", model.__class__.__name__)
            for fold, (train_index, test_index) in enumerate(kfold.split(X_train)):
                X_train_fold = X_train.iloc[train_index]
                X_test_fold = X_train.iloc[test_index]
                y_train_fold = y_train.iloc[train_index]
                y_test_fold = y_train.iloc[test_index]
                
                signature = infer_signature(X_train_fold, y_train_fold)
                model.fit(X_train_fold, y_train_fold)

                # Start nested MLflow run
                with mlflow.start_run(run_name=f"Fold {fold}", nested=True, experiment_id=experiment_id):
                    # Log metrics
                    model_uri = mlflow.sklearn.log_model(
                        model, "model", signature=signature
                    ).model_uri 
                    mlflow.evaluate(
                        model_uri,
                        pd.concat([X_test_fold, y_test_fold], axis=1),
                        targets="Credit_Score",
                        model_type="classifier",
                    )
            with mlflow.start_run(run_name=f"Final", nested=True, experiment_id=experiment_id):
                # Log metrics
                mlflow.evaluate(
                    model_uri,
                    pd.concat([X_test, y_test], axis=1),
                    targets="Credit_Score",
                    model_type="classifier",
                )

# %%
run_experiments("Default Models Comparison (without scaling)")
# Out:
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/28 16:40:01 WARNING mlflow.utils.validation: Tag value '[{"run_id": "c15f6cbb38d74df9b10d096af196eaf3", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:40:01 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/c15f6cbb38d74df9b10d096af196eaf3/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:40:04 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:40:04 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:40:04 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:40:05 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/28 16:40:19 WARNING mlflow.utils.validation: Tag value '[{"run_id": "2a2a22cf77d14b6b966b1fb387124996", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:40:19 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/2a2a22cf77d14b6b966b1fb387124996/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:40:21 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:40:21 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:40:21 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:40:22 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/28 16:40:36 WARNING mlflow.utils.validation: Tag value '[{"run_id": "e7a8610949054822aa11f1c3a00abb1f", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:40:36 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/e7a8610949054822aa11f1c3a00abb1f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:40:39 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:40:39 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:40:39 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:40:40 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/28 16:40:54 WARNING mlflow.utils.validation: Tag value '[{"run_id": "436d477797c64c55addcefb744894c9b", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:40:54 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/436d477797c64c55addcefb744894c9b/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:40:57 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:40:57 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:40:57 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:40:57 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 2024/08/28 16:41:12 WARNING mlflow.utils.validation: Tag value '[{"run_id": "870c9116ab1348bba8be58d44e423326", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:41:12 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/870c9116ab1348bba8be58d44e423326/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:41:14 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:41:14 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:41:14 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:41:15 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:41:21 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:41:21 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:41:21 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:41:22 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:41:32 WARNING mlflow.utils.validation: Tag value '[{"run_id": "93fcbdf47c0b4912925001cc53d47bc7", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:41:32 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/93fcbdf47c0b4912925001cc53d47bc7/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:41:34 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:41:34 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/28 16:41:35 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:41:35 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:41:45 WARNING mlflow.utils.validation: Tag value '[{"run_id": "1b3cada83b994d51a54571323265bfb9", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:41:46 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/1b3cada83b994d51a54571323265bfb9/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:41:48 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:41:48 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/28 16:41:48 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:41:49 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:41:59 WARNING mlflow.utils.validation: Tag value '[{"run_id": "c5f2dd7df8fd4091907abb8851253ad4", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:41:59 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/c5f2dd7df8fd4091907abb8851253ad4/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:42:01 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:42:01 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/28 16:42:01 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:42:02 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:42:12 WARNING mlflow.utils.validation: Tag value '[{"run_id": "f64dda323b3040c682c3c27ad0603bb2", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:42:12 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/f64dda323b3040c682c3c27ad0603bb2/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:42:15 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:42:15 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/28 16:42:15 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:42:16 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:42:26 WARNING mlflow.utils.validation: Tag value '[{"run_id": "e4e88ba06077439f9b9f0f293c9f8834", "artifact_path": "model", "utc_time_created": "2024-...' (5568 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:42:26 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/e4e88ba06077439f9b9f0f293c9f8834/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:42:28 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:42:28 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/28 16:42:28 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:42:29 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:42:35 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:42:35 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2981: UserWarning: The y_pred values do not sum to one. Starting from 1.5 thiswill result in an error.
#   warnings.warn(
# 2024/08/28 16:42:35 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:42:36 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:42:46 WARNING mlflow.utils.validation: Tag value '[{"run_id": "e690495bfb484bf38cec51c1f7444f56", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:42:46 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/e690495bfb484bf38cec51c1f7444f56/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:42:48 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:42:49 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:42:50 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:42:51 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:01 WARNING mlflow.utils.validation: Tag value '[{"run_id": "03db9ab4d1cc41a198511e63202ff342", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:43:01 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/03db9ab4d1cc41a198511e63202ff342/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:03 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:43:04 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:43:05 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:43:06 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:16 WARNING mlflow.utils.validation: Tag value '[{"run_id": "78ccb59c1cfd4674b6f8c6dae14b0190", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:43:16 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/78ccb59c1cfd4674b6f8c6dae14b0190/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:19 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:43:20 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:43:21 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:43:22 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:32 WARNING mlflow.utils.validation: Tag value '[{"run_id": "69a1c51af4a14f069bb84c741a3f0488", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:43:32 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/69a1c51af4a14f069bb84c741a3f0488/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:34 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:43:35 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:43:36 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:43:37 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:47 WARNING mlflow.utils.validation: Tag value '[{"run_id": "b58f5c6fda664ec6ba9d80c1aca522f4", "artifact_path": "model", "utc_time_created": "2024-...' (5572 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:43:47 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/b58f5c6fda664ec6ba9d80c1aca522f4/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:49 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:43:50 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# 2024/08/28 16:43:51 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/08/28 16:43:52 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:43:57 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# ...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:54:33 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:54:33 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:54:33 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:54:34 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:54:44 WARNING mlflow.utils.validation: Tag value '[{"run_id": "23c834216bfa4d42bffe07876480b818", "artifact_path": "model", "utc_time_created": "2024-...' (5567 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:54:44 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/23c834216bfa4d42bffe07876480b818/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:54:46 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:54:46 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:54:46 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:54:47 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:54:57 WARNING mlflow.utils.validation: Tag value '[{"run_id": "17d0b59701f0462d8ee559dbd7f21f73", "artifact_path": "model", "utc_time_created": "2024-...' (5567 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:54:57 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/17d0b59701f0462d8ee559dbd7f21f73/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:54:59 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:54:59 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:54:59 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:55:00 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:55:10 WARNING mlflow.utils.validation: Tag value '[{"run_id": "93aa1ceb38d444e29d933b993835417b", "artifact_path": "model", "utc_time_created": "2024-...' (5567 characters) is truncated to 5000 characters to meet the length limit.
# 2024/08/28 16:55:10 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under /app/mlflow_artifacts/93aa1ceb38d444e29d933b993835417b/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:55:12 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:55:12 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:55:13 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:55:14 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:406: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/08/28 16:55:19 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/08/28 16:55:19 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as multiclass dataset, number of classes is inferred as 3. If this is incorrect, please specify the `label_list` parameter in `evaluator_config`.
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:55:19 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/envs/mlflow_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024/08/28 16:55:20 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because it requires all label values to be numeric or boolean.

# %% [markdown]
# # With scaling

# %%
std_scaler = StandardScaler()
X_train = std_scaler.fit_transform(X_train)
X_test = std_scaler.transform(X_test)
run_experiment("Model Comparison Experiment (with default params and scaling)")
